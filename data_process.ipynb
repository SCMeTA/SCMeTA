# %%
from SCMeTA import Process

p = Process()

path = "data/exp074_250223_XP_single_cell/POS"
p.load(path=path)
# Out:
# [2025-06-06 17:30:10][INFO] Start loading data from data/exp074_250223_XP_single_cell/POS...
# Reading exp074_250523_XP_single_cell_POS_jurkat_3_007:   0%|          | 0/51467 [00:00<?, ?it/s]
# Reading exp074_250523_XP_single_cell_POS_mixed_02_011:   0%|          | 0/48945 [00:00<?, ?it/s]
#
#
# Reading exp074_250523_XP_single_cell_POS_jurkat_4_008:   0%|          | 0/52444 [00:00<?, ?it/s]
#
#
#
# Reading exp074_250523_XP_single_cell_POS_DND41_4_010:   0%|          | 0/48818 [00:00<?, ?it/s]
#
# Reading exp074_250523_XP_single_cell_POS_DND41_3_009:   0%|          | 0/48293 [00:00<?, ?it/s]
#
#
#
# Reading exp074_250523_XP_single_cell_POS_DND41_4_010:   0%|          | 1/48818 [00:00<8:45:49,  1.55it/s]
#
# Reading exp074_250523_XP_single_cell_POS_jurkat_3_007:   0%|          | 1/51467 [00:00<9:22:51,  1.52it/s][A
#
#
# Reading exp074_250523_XP_single_cell_POS_jurkat_4_008:   0%|          | 1/52444 [00:00<9:27:09,  1.54it/s]
# ...

# %%
p.clear_memory()
p.pre_process(resolution=0.01)
# Out:
# [2025-06-06 17:41:08][INFO] Memory cleared
# [2025-06-06 17:41:08][INFO] Start pre-processing data...
# [2025-06-06 17:41:39][INFO] Filter out the data with low occurrence.
# [2025-06-06 17:41:39][INFO] Pre-process finished.

# %%
p.process()
# Out:
# [2025-06-06 17:41:48][INFO] Start processing data...
# ...
# Denoising: 100%|██████████| 5/5 [00:13<00:00,  2.62s/it]
# [2025-06-06 17:42:26][INFO] Noise subtracted!
# [2025-06-06 17:42:36][INFO] Filter out the data with low SNR.
# [2025-06-06 17:42:36][INFO] Filter out the mat data.
# [2025-06-06 17:42:36][INFO] File name: exp074_250523_XP_single_cell_POS_DND41_4_010 Cells count: 190 Peaks count: 0
# [2025-06-06 17:42:36][INFO] File name: exp074_250523_XP_single_cell_POS_DND41_3_009 Cells count: 108 Peaks count: 0
# [2025-06-06 17:42:36][INFO] File name: exp074_250523_XP_single_cell_POS_mixed_02_011 Cells count: 99 Peaks count: 0
# [2025-06-06 17:42:36][INFO] File name: exp074_250523_XP_single_cell_POS_jurkat_3_007 Cells count: 59 Peaks count: 0
# [2025-06-06 17:42:36][INFO] File name: exp074_250523_XP_single_cell_POS_jurkat_4_008 Cells count: 182 Peaks count: 0
# [2025-06-06 17:42:36][INFO] Memory cleared
# ...
