# %%
from SCMeTA import Process

p = Process()

path = "data/exp074_250223_XP_single_cell/POS"
p.load(path)
# Out:
# [2025-06-11 11:24:45][INFO] Start loading data from data/exp074_250223_XP_single_cell/POS...
# Reading exp074_250523_XP_single_cell_POS_jurkat_4_008:   0%|          | 0/52444 [00:00<?, ?it/s]
#
#
# Reading exp074_250523_XP_single_cell_POS_jurkat_3_007:   0%|          | 0/51467 [00:00<?, ?it/s]
#
# Reading exp074_250523_XP_single_cell_POS_mixed_02_011:   0%|          | 0/48945 [00:00<?, ?it/s]
# Reading exp074_250523_XP_single_cell_POS_DND41_4_010:   0%|          | 0/48818 [00:00<?, ?it/s]
#
#
#
# Reading exp074_250523_XP_single_cell_POS_DND41_3_009:   0%|          | 0/48293 [00:00<?, ?it/s]
#
#
#
# Reading exp074_250523_XP_single_cell_POS_jurkat_4_008:   0%|          | 1/52444 [00:00<11:11:12,  1.30it/s][A
#
# Reading exp074_250523_XP_single_cell_POS_mixed_02_011:   0%|          | 1/48945 [00:00<10:21:07,  1.31it/s]
# Reading exp074_250523_XP_single_cell_POS_DND41_4_010:   0%|          | 1/48818 [00:00<10:18:25,  1.32it/s]
#
#
# ...

# %%
p.pre_process()
p.process()
# Out:
# [2025-06-11 11:36:18][INFO] Start pre-processing data...
# [2025-06-11 11:36:51][INFO] Filter out the data with low occurrence.
# [2025-06-11 11:36:51][INFO] Pre-process finished.
# [2025-06-11 11:36:51][INFO] Start processing data...
# ...
# Processing...:  14%|█▍        | 1/7 [00:24<02:24, 24.15s/it]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 p.pre_process()
# ----> 2 p.process()
#
# File ~/Developer/SCMeTA/SCMeTA/SCMeTA/core/cluster.py:417, in Process.process(self, max_ratio, adjacent, snr, resolution, threshold, lock_mz, filter_method)
#     415 self.gen_mat()
#     416 progress_bar.update(1)
# --> 417 self.round_mat(resolution=resolution)
#     418 progress_bar.update(1)
#     419 self.denoise(max_ratio=max_ratio)
#
# File ~/Developer/SCMeTA/SCMeTA/SCMeTA/core/cluster.py:208, in Process.round_mat(self, resolution, file_name)
# ...

# %%
p.save(data_type="process", path="data/exp074_250223_XP_single_cell/Process")
# Out:
# [2025-06-11 11:03:40][INFO] Data saved!
# Processing...:  14%|█▍        | 1/7 [05:32<02:21, 23.58s/it]
